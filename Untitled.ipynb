# %%
import pandas as pd
df = pd.read_csv("churn.csv")

# %%
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  Day Charge  Eve Calls  \
# 0               1      0           0           1  ...       45.07         99
# 1               1      0           0           1  ...       27.47        103
# 2               0      0           0           0  ...       41.38        110
# 3               2      0           1           0  ...       50.90         88
# 4               3      0           1           0  ...       28.34        122
#
# ...

# %%
#remove/replace special characters and white spaces
df.columns = [i.replace(' ','_').replace("'",'').lower() for i in df.columns]
#Check out how the resultant dataset look like
df.head()
# Out:
#    account_length  vmail_message  day_mins  eve_mins  night_mins  intl_mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    custserv_calls  churn  intl_plan  vmail_plan  ...  day_charge  eve_calls  \
# 0               1      0          0           1  ...       45.07         99
# 1               1      0          0           1  ...       27.47        103
# 2               0      0          0           0  ...       41.38        110
# 3               2      0          1           0  ...       50.90         88
# 4               3      0          1           0  ...       28.34        122
#
# ...

# %%
def calc_total_mins(day_mins,eve_mins):
    "Output: total_mins"
    total_mins = day_mins + eve_mins
    return total_mins

# %%
df.day_mins[0]
# Out:
# 265.1

# %%
calc_total_mins(df.day_mins[0], df.eve_mins[0])
# Out:
# 462.5
